# %%
# Imports
import numpy as np
import pandas as pd
from collections import Counter, defaultdict

#visual
import seaborn as sns 
import matplotlib.pyplot as plt
import missingno as mno
from imblearn.over_sampling import SMOTE
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import plot_roc_curve

#learning
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, LabelBinarizer
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import precision_score, accuracy_score, confusion_matrix, f1_score, recall_score
from sklearn.utils.multiclass import unique_labels
from sklearn.linear_model import SGDClassifier, RidgeClassifier, LogisticRegression
from sklearn.svm import LinearSVC, SVC
from sklearn.gaussian_process.kernels import RBF
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier
from keras.models import Sequential
from keras.layers.core import Dense
from keras.layers.core import Activation
from sklearn import metrics

# import warnings filter
from warnings import simplefilter

# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# # Data

# %%
# Naming the columns
names = ['account_status', 'duration', 'credit_history',
             'purpose', 'credit_amount', 'savings_account', 'employment_since',
             'installment_rate', 'personal_status_sex', 'guarantors', 
             'residence_since', 'property', 'age', 'other_installment_plans',
             'housing', 'number_of_credits', 'job', 'people_to_maintain',
             'phone', 'foreign_worker', 'creditworthy']

df = pd.read_csv('kredit.dat', header=None, sep="\t", names=names)
df.shape
# Out:
# (1000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   account_status           1000 non-null   object
#  1   duration                 1000 non-null   int64
#  2   credit_history           1000 non-null   object
#  3   purpose                  1000 non-null   object
#  4   credit_amount            1000 non-null   int64
#  5   savings_account          1000 non-null   object
#  6   employment_since         1000 non-null   object
#  7   installment_rate         1000 non-null   int64
#  8   personal_status_sex      1000 non-null   object
#  9   guarantors               1000 non-null   object
#  10  residence_since          1000 non-null   int64
#  11  property                 1000 non-null   object
#  12  age                      1000 non-null   int64
#  13  other_installment_plans  1000 non-null   object
#  14  housing                  1000 non-null   object
#  15  number_of_credits        1000 non-null   int64
#  16  job                      1000 non-null   object
#  17  people_to_maintain       1000 non-null   int64
#  18  phone                    1000 non-null   object
#  19  foreign_worker           1000 non-null   object
#  20  creditworthy             1000 non-null   int64
# dtypes: int64(8), object(13)
# memory usage: 164.2+ KB

# %%
# Select the Last column - target variable
df.creditworthy.replace([1,2], [1,0], inplace=True)
label = df['creditworthy']
df_new = df.drop(columns=['creditworthy'])
df_new.shape
# Out:
# (1000, 20)

# %%
print(f'Number of data points: {df_new.shape[0]}')
print(f'Number of Attributes: {df_new.shape[1]}')
df_new.head(10)
# Out:
# Number of data points: 1000
# Number of Attributes: 20
#   account_status  duration credit_history purpose  credit_amount  \
# 0            A14        36            A32       ?           2299
# 1            A12        18            A32     A46           1239
# 2            A13        24            A32     A40            947
# 3            A14        15            A33     A43           1478
# 4            A14        24            A32     A40           1525
# 5            A12        24            A34     A40           3878
# 6            A14        24            A32     A41           6313
# 7            A11        21            A33     A46           3414
# 8            A11        24            A34     A41           6419
# 9            A12        18            A32       ?           1924
#
#   savings_account employment_since  installment_rate personal_status_sex  \
# 0             A63                ?                 4                 A93
# 1             A65              A73                 4                 A93
# 2             A61              A74                 4                 A93
# 3             A61              A73                 4                 A94
# 4             A64              A74                 4                 A92
# 5             A62                ?                 4                 A91
# 6             A65              A75                 3                 A93
# 7             A61                ?                 2                 A93
# 8             A61                ?                 2                 A92
# 9             A65              A72                 4                 A92
#
#   guarantors  residence_since property  age other_installment_plans housing  \
# 0       A101                4     A123   39                    A143    A152
# 1       A101                4     A124   61                    A143    A153
# 2       A101                3     A124   38                    A141    A153
# 3       A101                3     A121   33                    A141    A152
# 4       A101                3     A123   34                    A143    A152
# 5       A101                2     A123   37                    A143    A152
# 6       A101                4     A123   41                    A143    A152
# 7       A101                1     A122   26                    A143    A152
# 8       A101                4     A124   44                    A143    A153
# 9       A101                3     A121   27                    A143    A151
#
#    number_of_credits   job  people_to_maintain phone foreign_worker
# 0                  1  A173                   1  A191              ?
# 1                  1     ?                   1  A191           A201
# 2                  1     ?                   2  A191              ?
# 3                  2  A173                   1  A191           A201
# 4                  1  A173                   2  A192           A201
# 5                  1     ?                   1  A192           A201
# 6                  1  A174                   2  A192           A201
# 7                  2  A173                   1  A191           A201
# 8                  2  A174                   2  A192           A201
# 9                  1  A173                   1  A191              ?

# %%
#Change the 'phone' and 'foreign_worker' coloum values into numeric one
#Telephone: A191: none; A192: yes, registered under the customers name
#Foreign worker: A201: yes; A202: no

df_new.replace('A201', 1, inplace=True)
df_new.replace('A202', 0, inplace=True)
df_new.replace('A191', 0, inplace=True)
df_new.replace('A192', 1, inplace=True)

# %% [markdown]
# # Handle Missing Values

# %%
# For more convenient operations for missing values, replace ? with NaN
# As there are too many missing values to remove these points from the dataset
df_new.replace("?", np.nan, inplace=True)

# %%
print(f'Number of Missing Values:\n\n{df_new.isnull().sum()}')
# Out:
# Number of Missing Values:
#
# account_status               0
# duration                     0
# credit_history               0
# purpose                    173
# credit_amount                0
# savings_account              0
# employment_since           496
# installment_rate             0
# personal_status_sex          0
# guarantors                   0
# residence_since              0
# property                     0
# age                          0
# other_installment_plans      0
# housing                      0
# number_of_credits            0
# job                        232
# people_to_maintain           0
# phone                        0
# foreign_worker             360
# dtype: int64

# %%
print(f'Without omiting the missing values columns {df_new.shape}')

# Collect the missing columns
missing_columns = ['purpose', 'employment_since', 'job', 'foreign_worker']

# create df with features that are fully available; delete the column with contains Null values
df_new = df_new.dropna(axis=1, how='any')

print(f'Omiting the missing values columns {df_new.shape}')
# Out:
# Without omiting the missing values columns (1000, 20)
# Omiting the missing values columns (1000, 16)

# %%
# Percentage of missing values
df[missing_columns].isnull().sum()/len(df) * 100
# Out:
# purpose             0.0
# employment_since    0.0
# job                 0.0
# foreign_worker      0.0
# dtype: float64

# %%
print(f'Number of Missing Values:\n\n{df_new.isnull().sum()}')
# Out:
# Number of Missing Values:
#
# account_status             0
# duration                   0
# credit_history             0
# credit_amount              0
# savings_account            0
# installment_rate           0
# personal_status_sex        0
# guarantors                 0
# residence_since            0
# property                   0
# age                        0
# other_installment_plans    0
# housing                    0
# number_of_credits          0
# people_to_maintain         0
# phone                      0
# dtype: int64

# %% [markdown]
# # Visualize data

# %%
df['installment_rate'].value_counts(ascending=True)
# Out:
# 1    136
# 3    157
# 2    231
# 4    476
# Name: installment_rate, dtype: int64

# %%
print(df.hist(figsize = (10,13)))
# Out:
# [[<AxesSubplot:title={'center':'duration'}>
#   <AxesSubplot:title={'center':'credit_amount'}>
#   <AxesSubplot:title={'center':'installment_rate'}>]
#  [<AxesSubplot:title={'center':'residence_since'}>
#   <AxesSubplot:title={'center':'age'}>
#   <AxesSubplot:title={'center':'number_of_credits'}>]
#  [<AxesSubplot:title={'center':'people_to_maintain'}>
#   <AxesSubplot:title={'center':'creditworthy'}> <AxesSubplot:>]]

# %%
print(df['personal_status_sex'].value_counts())

fig, ax = plt.subplots(figsize=(10,4))
df['personal_status_sex'].value_counts().plot(kind='bar')
plt.show()
# A91: male: divorced/separated A92: female: divorced/separated/married
# A93: male: single # A94: male: married/widowed
# Out:
# A93    548
# A92    310
# A94     92
# A91     50
# Name: personal_status_sex, dtype: int64

# %%
df.groupby(['residence_since'])['creditworthy'].value_counts()
# Out:
# residence_since  creditworthy
# 1                1                94
#                  0                36
# 2                1               211
#                  0                97
# 3                1               106
#                  0                43
# 4                1               289
#                  0               124
# Name: creditworthy, dtype: int64

# %%
_, axes = plt.subplots(1, 3, figsize=(13,6))

sns.countplot(x='creditworthy', hue='residence_since', data=df, ax=axes[0]);
sns.countplot(x='creditworthy', hue='credit_history', data=df, ax=axes[1]);
sns.countplot(x='creditworthy', hue='personal_status_sex', data=df, ax=axes[2]);
plt.tight_layout()

# %% [markdown]
# # Categorical

# %%
def categorical_numerical_split(df):
    categorical = [att for att in df.columns if df[att].dtype == 'object']
    numerical = [att for att in df.columns if df[att].dtype == 'int64']
    return categorical, numerical

categorical, numerical = categorical_numerical_split(df)

print(f'Categorical features:\n{categorical}\n')
print(f'Numerical features:\n{numerical}')
# Out:
# Categorical features:
# ['account_status', 'credit_history', 'purpose', 'savings_account', 'employment_since', 'personal_status_sex', 'guarantors', 'property', 'other_installment_plans', 'housing', 'job', 'phone', 'foreign_worker']
#
# Numerical features:
# ['duration', 'credit_amount', 'installment_rate', 'residence_since', 'age', 'number_of_credits', 'people_to_maintain', 'creditworthy']

# %%
# return number of unique elements in the object

df[categorical].nunique()
# Out:
# account_status              4
# credit_history              5
# purpose                    11
# savings_account             5
# employment_since            6
# personal_status_sex         4
# guarantors                  3
# property                    4
# other_installment_plans     3
# housing                     3
# job                         5
# phone                       2
# foreign_worker              3
# dtype: int64

# %%
# Feature representation

print("Unique categorical values:")
for att in df.select_dtypes(include=[object]):
    print(att,":", df[att].unique())
# Out:
# Unique categorical values:
# account_status : ['A14' 'A12' 'A13' 'A11']
# credit_history : ['A32' 'A33' 'A34' 'A30' 'A31']
# purpose : ['?' 'A46' 'A40' 'A43' 'A41' 'A42' 'A49' 'A410' 'A45' 'A48' 'A44']
# savings_account : ['A63' 'A65' 'A61' 'A64' 'A62']
# employment_since : ['?' 'A73' 'A74' 'A75' 'A72' 'A71']
# personal_status_sex : ['A93' 'A94' 'A92' 'A91']
# guarantors : ['A101' 'A102' 'A103']
# property : ['A123' 'A124' 'A121' 'A122']
# other_installment_plans : ['A143' 'A141' 'A142']
# housing : ['A152' 'A153' 'A151']
# job : ['A173' '?' 'A174' 'A172' 'A171']
# phone : ['A191' 'A192']
# foreign_worker : ['?' 'A201' 'A202']

# %% [markdown]
# <b><h2>Encodes nominal features to numeric features</h2></b>
#
# Many machine learning algorithms cannot operate on label data directly. They require all input variables and output variables to be numeric.<br>
#
# return: data frame with all-numeric features

# %%
def str_to_num(df):
    # create a new df with categorical features only, encoded as numbers
    categorical, numerical = categorical_numerical_split(df)
    
    enc = LabelEncoder()
    df_encoded = df[categorical].apply(lambda x: enc.fit_transform(x))

    df_encoded_concat = pd.concat([df_encoded, df[numerical]], axis=1)
    
    # Create a dict to decode numeric values; returns a dictionary-like object
    d = defaultdict()
    
    for col_name in df[categorical]:
        # e.g.: account_status_A14 :  3
        for unique_str_val, unique_num_val in zip(df[col_name].unique(), df_encoded[col_name].unique()):
                d[col_name + '_' + unique_str_val] = unique_num_val            
    
    return df_encoded_concat , d

# %%
df_new_enc, df_new_enc_dict = str_to_num(df_new)

# Print out new numericaly encoded features
for k,v in df_new_enc_dict.items():
    print(k, ': ', v)
# Out:
# account_status_A14 :  3
# account_status_A12 :  1
# account_status_A13 :  2
# account_status_A11 :  0
# credit_history_A32 :  2
# credit_history_A33 :  3
# credit_history_A34 :  4
# credit_history_A30 :  0
# credit_history_A31 :  1
# savings_account_A63 :  2
# savings_account_A65 :  4
# savings_account_A61 :  0
# savings_account_A64 :  3
# savings_account_A62 :  1
# personal_status_sex_A93 :  2
# personal_status_sex_A94 :  3
# personal_status_sex_A92 :  1
# personal_status_sex_A91 :  0
# guarantors_A101 :  0
# guarantors_A102 :  1
# guarantors_A103 :  2
# property_A123 :  2
# property_A124 :  3
# property_A121 :  0
# property_A122 :  1
# other_installment_plans_A143 :  2
# other_installment_plans_A141 :  0
# other_installment_plans_A142 :  1
# housing_A152 :  1
# housing_A153 :  2
# housing_A151 :  0

# %%
# Make sure there are still 16 feature
print(df_new_enc.shape)
# Out:
# (1000, 16)

# %% [markdown]
# For categorical variables where no such ordinal relationship exists, a one-hot encoding can be applied to the integer representation.
#
# <b> One-Hot Encoding: </b> The integer encoded variable is removed and a new binary variable is added for each unique integer value.
#
# <b>df:</b> dataframe
#
# <b>to_one_hot:</b> list of columns to encode
#
# <b>return:</b> encoded df

# %%
def to_one_hot(df, verbose=False):
    categorical, numerical = categorical_numerical_split(df)
    
    # 1-hot encoding for the categorical variables
    df_only_one_hot = pd.get_dummies(df[categorical])
    
    if verbose == True:
        print(f'new 1-hot-encoded variables:\n {list(df_only_one_hot.columns)}')
    
    # Concatenate numerical and categorical data
    df_new_onehot = pd.concat([df[numerical], df_only_one_hot], axis = 1)
    
    if verbose == True:
        print(f'Shape: {df_new_onehot.shape}')
        df_new_onehot.head()
    
    return df_new_onehot

# %%
# Fatures that shoud be encoded for X_train
df_new_onehot = to_one_hot(df_new, verbose=True)
# Out:
# new 1-hot-encoded variables:
#  ['account_status_A11', 'account_status_A12', 'account_status_A13', 'account_status_A14', 'credit_history_A30', 'credit_history_A31', 'credit_history_A32', 'credit_history_A33', 'credit_history_A34', 'savings_account_A61', 'savings_account_A62', 'savings_account_A63', 'savings_account_A64', 'savings_account_A65', 'personal_status_sex_A91', 'personal_status_sex_A92', 'personal_status_sex_A93', 'personal_status_sex_A94', 'guarantors_A101', 'guarantors_A102', 'guarantors_A103', 'property_A121', 'property_A122', 'property_A123', 'property_A124', 'other_installment_plans_A141', 'other_installment_plans_A142', 'other_installment_plans_A143', 'housing_A151', 'housing_A152', 'housing_A153']
# Shape: (1000, 39)

# %%
df_new_onehot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   duration                      1000 non-null   int64
#  1   credit_amount                 1000 non-null   int64
#  2   installment_rate              1000 non-null   int64
#  3   residence_since               1000 non-null   int64
#  4   age                           1000 non-null   int64
#  5   number_of_credits             1000 non-null   int64
#  6   people_to_maintain            1000 non-null   int64
#  7   phone                         1000 non-null   int64
#  8   account_status_A11            1000 non-null   uint8
#  9   account_status_A12            1000 non-null   uint8
#  10  account_status_A13            1000 non-null   uint8
#  11  account_status_A14            1000 non-null   uint8
#  12  credit_history_A30            1000 non-null   uint8
#  13  credit_history_A31            1000 non-null   uint8
#  14  credit_history_A32            1000 non-null   uint8
#  15  credit_history_A33            1000 non-null   uint8
#  16  credit_history_A34            1000 non-null   uint8
#  17  savings_account_A61           1000 non-null   uint8
#  18  savings_account_A62           1000 non-null   uint8
#  19  savings_account_A63           1000 non-null   uint8
#  20  savings_account_A64           1000 non-null   uint8
#  21  savings_account_A65           1000 non-null   uint8
#  22  personal_status_sex_A91       1000 non-null   uint8
#  23  personal_status_sex_A92       1000 non-null   uint8
#  24  personal_status_sex_A93       1000 non-null   uint8
#  25  personal_status_sex_A94       1000 non-null   uint8
#  26  guarantors_A101               1000 non-null   uint8
#  27  guarantors_A102               1000 non-null   uint8
#  28  guarantors_A103               1000 non-null   uint8
#  29  property_A121                 1000 non-null   uint8
#  30  property_A122                 1000 non-null   uint8
#  31  property_A123                 1000 non-null   uint8
#  32  property_A124                 1000 non-null   uint8
#  33  other_installment_plans_A141  1000 non-null   uint8
#  34  other_installment_plans_A142  1000 non-null   uint8
#  35  other_installment_plans_A143  1000 non-null   uint8
#  36  housing_A151                  1000 non-null   uint8
#  37  housing_A152                  1000 non-null   uint8
#  38  housing_A153                  1000 non-null   uint8
# dtypes: int64(8), uint8(31)
# memory usage: 92.9 KB

# %% [markdown]
# # Check the balanced of the dataset

# %%
print(label.value_counts())

label.value_counts().plot(kind='bar', label= 'Target Values')
# Out:
# 1    700
# 0    300
# Name: creditworthy, dtype: int64
# <AxesSubplot:>

# %% [markdown]
# 1 = good, trustworthy
#
# 0 = bad, Not trustworthy
#
# There are more than twice as many creditworthy examples

# %% [markdown]
# A problem with imbalanced classification is that there are too few examples of the minority class for a model to effectively learn the decision boundary. One way to solve this problem is to oversample the examples in the minority class.
#
# The most common technique is called <b>SMOTE (Synthetic Minority Over-sampling Technique).</b>
# In simple terms, it looks at the feature space for the minority class data points
# and considers its k nearest neighbours.

# %%
def balance_data(df,label):
    sm = SMOTE(random_state=7)

    # Fit the model to generate the data.
    cols = df.columns
    df, label = sm.fit_resample(df, label)
    df = pd.DataFrame(df)
    label = pd.Series(label)

    df.columns = cols
    return df,label

# %%
label_orig = label
df_new_enc, label_enc = balance_data(df_new_enc,label_orig)
df_new_onehot, label_onehot = balance_data(df_new_onehot, label_orig)

print(label_enc.value_counts())

label_enc.value_counts().plot(kind='bar', label= 'Target Values')
# Out:
# 0    700
# 1    700
# Name: creditworthy, dtype: int64
# <AxesSubplot:>

# %% [markdown]
# 1 = good, trustworthy
#
# 0 = bad, Not trustworthy

# %%
df_new_enc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400 entries, 0 to 1399
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   account_status           1400 non-null   int32
#  1   credit_history           1400 non-null   int32
#  2   savings_account          1400 non-null   int32
#  3   personal_status_sex      1400 non-null   int32
#  4   guarantors               1400 non-null   int32
#  5   property                 1400 non-null   int32
#  6   other_installment_plans  1400 non-null   int32
#  7   housing                  1400 non-null   int32
#  8   duration                 1400 non-null   int64
#  9   credit_amount            1400 non-null   int64
#  10  installment_rate         1400 non-null   int64
#  11  residence_since          1400 non-null   int64
#  12  age                      1400 non-null   int64
#  13  number_of_credits        1400 non-null   int64
#  14  people_to_maintain       1400 non-null   int64
#  15  phone                    1400 non-null   int64
# dtypes: int32(8), int64(8)
# memory usage: 131.4 KB

# %%
print(df_new_onehot.shape)

label_onehot.value_counts().plot(kind='bar', label= 'Target Values')
# Out:
# (1400, 39)
# <AxesSubplot:>

# %% [markdown]
# 1 = good, trustworthy
#
# 0 = bad, Not trustworthy

# %% [markdown]
# # Evaluation Functions

# %%
#10-fold Cross Validation on training and validation data
def cross_validate(clf, X_train, y_train, metrics=['precision', 'accuracy']):
    for metric in metrics: 
        scores = cross_val_score(clf, X_train, y_train, cv=10, scoring=metric)
        
        # The mean score and standard deviation of the score estimate
        print("Cross Validation %s: %0.2f (+/- %0.2f)" % (metric, scores.mean(), scores.std()))
    
    return 

#Fits classifier
def train(clf, X_train, y_train):
    print(f'Training a {clf.__class__.__name__}')
    print(f'with a training set size of {len(X_train)}')
    clf.fit(X_train, y_train)
    return clf

#Predict on unseen test data
def predict(clf, X_test):    
    y_pred = clf.predict(X_test)
    return y_pred

#Evaluate on Precision and Accuracy
def evaluate_test(y_test, y_pred):
    print(f'Test Precision Score: {precision_score(y_test, y_pred)}')
    print(f'Test Recall Score: {recall_score(y_test, y_pred)}')
    print(f'Test Accuracy Score: {accuracy_score(y_test, y_pred)}')   
    print(f'Test F1-score Score: {f1_score(y_test, y_pred)}')
    
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    print(f'Test Confusion Matrix: \n {confusion_matrix(y_test, y_pred)}')
    print(f'Number of False Positives: {fp}')
    
    return 

def train_predict(clf, X_train, y_train, X_test, y_test=None):
    # Train the classifier
    clf = train(clf, X_train, y_train)
    
    # Predict labes
    y_pred = predict(clf, X_test)
    
    return y_pred

# %% [markdown]
# # Random Forest

# %%
df_news = [df_new_enc, df_new_onehot]
labels = [label_enc, label_onehot]
names = ['Numerically Encoded Features: ', 'One-hot Encoded Features']

for df_new_encoded, lab, name in zip(df_news, labels, names):
    print('\n',name)
    print(df_new_encoded.shape)
    
    # Spliting X and y into train and test version
    X_train, X_test, y_train, y_test = train_test_split(df_new_encoded, lab, test_size = 0.25, random_state=4)

    clf = RandomForestClassifier(n_estimators=100, random_state=33)
    y_pred = train_predict(clf, X_train, y_train, X_test, y_test)
    evaluate_test(y_test, y_pred)
# Out:
#  Numerically Encoded Features:
# (1400, 16)
# Training a RandomForestClassifier
# with a training set size of 1050
# Test Precision Score: 0.8268156424581006
# Test Recall Score: 0.8176795580110497
# Test Accuracy Score: 0.8171428571428572
# Test F1-score Score: 0.8222222222222223
# Test Confusion Matrix:
#  [[138  31]
#  [ 33 148]]
# Number of False Positives: 31
#
#  One-hot Encoded Features
# (1400, 39)
# Training a RandomForestClassifier
# with a training set size of 1050
# Test Precision Score: 0.8369565217391305
# Test Recall Score: 0.850828729281768
# Test Accuracy Score: 0.8371428571428572
# Test F1-score Score: 0.8438356164383561
# Test Confusion Matrix:
#  [[139  30]
#  [ 27 154]]
# Number of False Positives: 30

# %%
X_train, X_test, y_train, y_test = train_test_split(df_new_enc, label_enc, test_size = 0.25)

train_accuracies = []
test_accuracies = []

for i in range(1,50):
    clf = RandomForestClassifier(n_estimators=i, max_depth=i)
    clf.fit(X_train, y_train)
    score_train = clf.score(X_train,y_train)
    score_test = clf.score(X_test,y_test)
    train_accuracies.append(score_train)
    test_accuracies.append(score_test)

# %%
plt.plot(train_accuracies, label='train accuracy')
plt.plot(test_accuracies, label='test accuracy')
plt.legend()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(df_new_onehot, label_onehot, test_size = 0.25)

train_accuracies = []
test_accuracies = []

for i in range(1,50):
    clf = RandomForestClassifier(n_estimators=i, max_depth=i)
    clf.fit(X_train, y_train)
    score_train = clf.score(X_train,y_train)
    score_test = clf.score(X_test,y_test)
    train_accuracies.append(score_train)
    test_accuracies.append(score_test)

# %%
plt.plot(train_accuracies, label='train accuracy')
plt.plot(test_accuracies, label='test accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Visualize the most important features

# %%
def display_feature_importance(trained_clf):

    # Print the name and gini importance of each feature
    importances = trained_clf.feature_importances_
    print(f'\n Feature Importance, sums up to 1:')
    for feature in zip(X_train.columns, importances):
        print(feature)
        
    # Visualise Feature Importance:
    indices = np.argsort(trained_clf.feature_importances_)
    plt.figure(figsize=(10,8))
    plt.title('Feature Importances')
    plt.barh(range(len(indices)), importances[indices], color='g', align='center')
    plt.yticks(range(len(indices)), [X_train.columns[i] for i in indices])
    plt.xlabel('Relative Importance')
    plt.show()
    
    return

# %%
X_train, X_test, y_train, y_test = train_test_split(df_new_enc, label_enc, test_size = 0.25)

clf_enc = RandomForestClassifier()
y_pred = train_predict(clf_enc, X_train, y_train, X_test, y_test)
display_feature_importance(clf_enc)
# Out:
# Training a RandomForestClassifier
# with a training set size of 1050
#
#  Feature Importance, sums up to 1:
# ('account_status', 0.19568985548210724)
# ('credit_history', 0.08452328588211698)
# ('savings_account', 0.052886141755273314)
# ('personal_status_sex', 0.050018088328375135)
# ('guarantors', 0.02546888542345625)
# ('property', 0.03674920691202278)
# ('other_installment_plans', 0.03311698063981581)
# ('housing', 0.03232822834087928)
# ('duration', 0.1034165035084955)
# ('credit_amount', 0.14113944686680868)
# ('installment_rate', 0.040345709667206034)
# ('residence_since', 0.05211689702690152)
# ('age', 0.09924662551314718)
# ('number_of_credits', 0.018513920326635902)
# ('people_to_maintain', 0.011506029580434675)
# ('phone', 0.022934194746323702)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_new_onehot, label_onehot, test_size = 0.25)

clf_onehot = RandomForestClassifier()
y_pred = train_predict(clf_onehot, X_train, y_train, X_test, y_test)
display_feature_importance(clf_onehot)
# Out:
# Training a RandomForestClassifier
# with a training set size of 1050
#
#  Feature Importance, sums up to 1:
# ('duration', 0.08489713184645975)
# ('credit_amount', 0.09688482413611796)
# ('installment_rate', 0.03362738178941331)
# ('residence_since', 0.03801012351766106)
# ('age', 0.07413622929583076)
# ('number_of_credits', 0.020466277254978103)
# ('people_to_maintain', 0.01083590291204844)
# ('phone', 0.026098702917992142)
# ('account_status_A11', 0.017149268075342384)
# ('account_status_A12', 0.022551266396742996)
# ('account_status_A13', 0.016377047548010167)
# ('account_status_A14', 0.12578171148624637)
# ('credit_history_A30', 0.004293990256618435)
# ('credit_history_A31', 0.0047772302555008864)
# ('credit_history_A32', 0.022356443352778567)
# ('credit_history_A33', 0.011159803455041003)
# ('credit_history_A34', 0.04879815702778078)
# ('savings_account_A61', 0.0157325115868744)
# ('savings_account_A62', 0.010332181869936348)
# ('savings_account_A63', 0.011620036733362411)
# ('savings_account_A64', 0.007379577317262714)
# ('savings_account_A65', 0.033381113172950234)
# ('personal_status_sex_A91', 0.0071101618462856234)
# ('personal_status_sex_A92', 0.01751896985795079)
# ('personal_status_sex_A93', 0.024949507240146444)
# ('personal_status_sex_A94', 0.011893265995404136)
# ('guarantors_A101', 0.01226909098337194)
# ('guarantors_A102', 0.0055531133900679035)
# ('guarantors_A103', 0.009147051478717418)
# ('property_A121', 0.029942736873112108)
# ('property_A122', 0.017174825029593208)
# ('property_A123', 0.021577325035402672)
# ('property_A124', 0.00976967033075416)
# ('other_installment_plans_A141', 0.012421187575190862)
# ('other_installment_plans_A142', 0.006042194274291157)
# ('other_installment_plans_A143', 0.02539087638673738)
# ('housing_A151', 0.012984591837689664)
# ('housing_A152', 0.031236355880419807)
# ('housing_A153', 0.008372163779915455)

# %% [markdown]
# # Correlation Matrix between features

# %%
def plot_corr_matrix(df):
    # Sample figsize in inches
    fig, ax = plt.subplots(figsize=(10,10))         
    
    corr = df.corr() # find the pairwise correlation of all columns in the dataframe
    sns.heatmap(corr, cmap='YlGnBu', ax=ax)
    ax.set_title("Correlation Matrix", fontsize=14)
    plt.show()
    return

plot_corr_matrix(df_new_enc)

# %%
def plot_corr_matrix(df):
    # Sample figsize in inches
    fig, ax = plt.subplots(figsize=(10,10))         
    # Imbalanced DataFrame Correlation
    corr = df.corr()
    sns.heatmap(corr, cmap='YlGnBu', ax=ax)
    ax.set_title("Correlation Matrix", fontsize=14)
    plt.show()
    return

plot_corr_matrix(df_new_onehot)

# %% [markdown]
# # Other Classifier

# %%
def other_classifier(clf, X_train, y_train, X_test, y_test):
    y_pred = train_predict(clf, X_train, y_train, X_test, y_test)
    evaluate_test(y_test, y_pred)

    class_names = np.array([0, 1])
                           
    titles_options = [("Confusion matrix, without normalization", None),
                  ("Normalized confusion matrix", 'true')]
    
    for title, normalize in titles_options:
        disp = plot_confusion_matrix(clf, X_test, y_test,
                                 display_labels=class_names,
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
        disp.ax_.set_title(title) 
        
        print(title)
        
        print(disp.confusion_matrix)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_new_enc, label_onehot, test_size = 0.25)

# %%
clf_svm = SVC(random_state = 9, kernel='linear')
other_classifier(clf_svm, X_train, y_train, X_test, y_test)
# Out:
# Training a SVC
# with a training set size of 1050
# Test Precision Score: 0.8187919463087249
# Test Recall Score: 0.7011494252873564
# Test Accuracy Score: 0.7742857142857142
# Test F1-score Score: 0.7554179566563468
# Test Confusion Matrix:
#  [[149  27]
#  [ 52 122]]
# Number of False Positives: 27
# Confusion matrix, without normalization
# [[149  27]
#  [ 52 122]]
# Normalized confusion matrix
# [[0.84659091 0.15340909]
#  [0.29885057 0.70114943]]

# %%
clf_log_reg = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial')
other_classifier(clf_log_reg, X_train, y_train, X_test, y_test)
# Out:
# Training a LogisticRegression
# with a training set size of 1050
# Test Precision Score: 0.7344632768361582
# Test Recall Score: 0.7471264367816092
# Test Accuracy Score: 0.74
# Test F1-score Score: 0.7407407407407407
# Test Confusion Matrix:
#  [[129  47]
#  [ 44 130]]
# Number of False Positives: 47
# Confusion matrix, without normalization
# [[129  47]
#  [ 44 130]]
# Normalized confusion matrix
# [[0.73295455 0.26704545]
#  [0.25287356 0.74712644]]

# %%
clf_tree = DecisionTreeClassifier(criterion='entropy', max_depth=8, min_samples_split=5, splitter = 'best', 
                                  min_samples_leaf = 25)
other_classifier(clf_tree, X_train, y_train, X_test, y_test)
# Out:
# Training a DecisionTreeClassifier
# with a training set size of 1050
# Test Precision Score: 0.7716049382716049
# Test Recall Score: 0.7183908045977011
# Test Accuracy Score: 0.7542857142857143
# Test F1-score Score: 0.7440476190476191
# Test Confusion Matrix:
#  [[139  37]
#  [ 49 125]]
# Number of False Positives: 37
# Confusion matrix, without normalization
# [[139  37]
#  [ 49 125]]
# Normalized confusion matrix
# [[0.78977273 0.21022727]
#  [0.2816092  0.7183908 ]]

# %%
ax = plt.gca()

clf_log_reg_disp = plot_roc_curve(clf_log_reg, X_test, y_test, ax=ax, alpha=0.8)
clf_tree_disp = plot_roc_curve(clf_tree, X_test, y_test, ax=ax, alpha=0.8)
#clf_tree_disp.plot(ax=ax, alpha=0.8)
clf_svm_disp = plot_roc_curve(clf_svm, X_test, y_test, ax=ax, alpha=0.8)
clf_enc = plot_roc_curve(clf_enc, X_test, y_test, ax=ax, alpha=0.8)

plt.show()

# %%
# define the model
model = Sequential()

# hidden layer mit 16 inputs, 10 units
model.add(Dense(20, input_dim=16, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(20, activation = 'relu'))

# output layer
model.add(Dense(1, activation='sigmoid'))

# For a multi-class classification problem
history = model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', 'binary_crossentropy'])


model.fit(X_train, y_train, epochs=150, batch_size=5)
# Out:
# Epoch 1/150
# 210/210 [==============================] - 1s 5ms/step - loss: 5.1157 - accuracy: 0.5000 - binary_crossentropy: 5.1157
# Epoch 2/150
# 210/210 [==============================] - 1s 3ms/step - loss: 2.2028 - accuracy: 0.5257 - binary_crossentropy: 2.2028
# Epoch 3/150
# 210/210 [==============================] - 0s 2ms/step - loss: 1.5962 - accuracy: 0.5648 - binary_crossentropy: 1.5962
# Epoch 4/150
# 210/210 [==============================] - 0s 2ms/step - loss: 3.7667 - accuracy: 0.5190 - binary_crossentropy: 3.7667
# Epoch 5/150
# 210/210 [==============================] - 0s 2ms/step - loss: 1.6429 - accuracy: 0.5600 - binary_crossentropy: 1.6429
# Epoch 6/150
# 210/210 [==============================] - 0s 2ms/step - loss: 2.0053 - accuracy: 0.5743 - binary_crossentropy: 2.0053
# Epoch 7/150
# 210/210 [==============================] - 0s 2ms/step - loss: 2.0005 - accuracy: 0.5895 - binary_crossentropy: 2.0005
# Epoch 8/150
# 210/210 [==============================] - 0s 2ms/step - loss: 2.4111 - accuracy: 0.5181 - binary_crossentropy: 2.4111
# Epoch 9/150
# 210/210 [==============================] - 1s 5ms/step - loss: 1.4818 - accuracy: 0.4971 - binary_crossentropy: 1.4818
# Epoch 10/150
# 210/210 [==============================] - 1s 7ms/step - loss: 1.2444 - accuracy: 0.5448 - binary_crossentropy: 1.2444: 0s - loss: 1.2664 - accuracy: 0.5290
# Epoch 11/150
# 210/210 [==============================] - 1s 4ms/step - loss: 1.1644 - accuracy: 0.5476 - binary_crossentropy: 1.1644
# Epoch 12/150
# 210/210 [==============================] - ETA: 0s - loss: 1.4696 - accuracy: 0.5521 - binary_crossentropy: 1.46 - 0s 2ms/step - loss: 1.4040 - accuracy: 0.5562 - binary_crossentropy: 1.4040
# Epoch 13/150
# 210/210 [==============================] - 0s 2ms/step - loss: 1.2374 - accuracy: 0.5705 - binary_crossentropy: 1.2374
# Epoch 14/150
# 210/210 [==============================] - 0s 2ms/step - loss: 1.0016 - accuracy: 0.5971 - binary_crossentropy: 1.0016
# Epoch 15/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.9287 - accuracy: 0.6048 - binary_crossentropy: 0.9287
# Epoch 16/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.8876 - accuracy: 0.6276 - binary_crossentropy: 0.8876
# Epoch 17/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.9723 - accuracy: 0.6076 - binary_crossentropy: 0.9723
# Epoch 18/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.9240 - accuracy: 0.6295 - binary_crossentropy: 0.9240
# Epoch 19/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.9247 - accuracy: 0.6162 - binary_crossentropy: 0.9247
# Epoch 20/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.8202 - accuracy: 0.6238 - binary_crossentropy: 0.8202
# Epoch 21/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.7144 - accuracy: 0.6581 - binary_crossentropy: 0.7144
# Epoch 22/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6975 - accuracy: 0.6676 - binary_crossentropy: 0.6975
# Epoch 23/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.8805 - accuracy: 0.6343 - binary_crossentropy: 0.8805
# Epoch 24/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.7455 - accuracy: 0.6600 - binary_crossentropy: 0.7455
# Epoch 25/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.7032 - accuracy: 0.6562 - binary_crossentropy: 0.7032
# Epoch 26/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6356 - accuracy: 0.6838 - binary_crossentropy: 0.6356
# Epoch 27/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.9106 - accuracy: 0.6467 - binary_crossentropy: 0.9106
# Epoch 28/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.7471 - accuracy: 0.6514 - binary_crossentropy: 0.7471
# Epoch 29/150
# 210/210 [==============================] - 0s 2ms/step - loss: 1.1707 - accuracy: 0.6067 - binary_crossentropy: 1.1707
# Epoch 30/150
# 210/210 [==============================] - 0s 2ms/step - loss: 1.0863 - accuracy: 0.5971 - binary_crossentropy: 1.0863
# Epoch 31/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.6581 - binary_crossentropy: 0.6864
# Epoch 32/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6970 - accuracy: 0.6638 - binary_crossentropy: 0.6970
# Epoch 33/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.7609 - accuracy: 0.6667 - binary_crossentropy: 0.7609
# Epoch 34/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6945 - accuracy: 0.6400 - binary_crossentropy: 0.6945
# Epoch 35/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.6377 - accuracy: 0.6705 - binary_crossentropy: 0.6377
# Epoch 36/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6918 - accuracy: 0.6819 - binary_crossentropy: 0.6918
# Epoch 37/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6381 - accuracy: 0.6895 - binary_crossentropy: 0.6381
# Epoch 38/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.7051 - accuracy: 0.6848 - binary_crossentropy: 0.7051
# Epoch 39/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6942 - accuracy: 0.6229 - binary_crossentropy: 0.6942
# Epoch 40/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6447 - accuracy: 0.6638 - binary_crossentropy: 0.6447
# Epoch 41/150
# 210/210 [==============================] - 1s 5ms/step - loss: 0.6684 - accuracy: 0.6143 - binary_crossentropy: 0.6684
# Epoch 42/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.6641 - accuracy: 0.5686 - binary_crossentropy: 0.6641
# Epoch 43/150
# 210/210 [==============================] - 1s 4ms/step - loss: 0.6757 - accuracy: 0.5419 - binary_crossentropy: 0.6757: 1s - loss: 0.6798 - accuracy: 0.5769 - bin
# Epoch 44/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6937 - accuracy: 0.5019 - binary_crossentropy: 0.6937
# Epoch 45/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6886 - accuracy: 0.5124 - binary_crossentropy: 0.6886
# Epoch 46/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6622 - accuracy: 0.5762 - binary_crossentropy: 0.6622
# Epoch 47/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6681 - accuracy: 0.5676 - binary_crossentropy: 0.6681
# Epoch 48/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.5029 - binary_crossentropy: 0.6923
# Epoch 49/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6831 - accuracy: 0.5286 - binary_crossentropy: 0.6831
# Epoch 50/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6533 - accuracy: 0.5943 - binary_crossentropy: 0.6533
# Epoch 51/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6895 - accuracy: 0.5229 - binary_crossentropy: 0.6895
# Epoch 52/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6936 - accuracy: 0.4962 - binary_crossentropy: 0.6936
# Epoch 53/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.4752 - binary_crossentropy: 0.6934
# Epoch 54/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6930 - accuracy: 0.4924 - binary_crossentropy: 0.6930
# Epoch 55/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6929 - accuracy: 0.4829 - binary_crossentropy: 0.6929
# Epoch 56/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6926 - accuracy: 0.4857 - binary_crossentropy: 0.6926
# Epoch 57/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6922 - accuracy: 0.5048 - binary_crossentropy: 0.6922
# Epoch 58/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6763 - accuracy: 0.5010 - binary_crossentropy: 0.6763
# Epoch 59/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6929 - accuracy: 0.5048 - binary_crossentropy: 0.6929
# Epoch 60/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6935 - accuracy: 0.4857 - binary_crossentropy: 0.6935
# Epoch 61/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.4800 - binary_crossentropy: 0.6934
# Epoch 62/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.4848 - binary_crossentropy: 0.6934
# Epoch 63/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.4933 - binary_crossentropy: 0.6934
# Epoch 64/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.5038 - binary_crossentropy: 0.6933
# Epoch 65/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6935 - accuracy: 0.4857 - binary_crossentropy: 0.6935
# Epoch 66/150
# 210/210 [==============================] - 1s 4ms/step - loss: 0.6934 - accuracy: 0.5038 - binary_crossentropy: 0.6934
# Epoch 67/150
# 210/210 [==============================] - 1s 5ms/step - loss: 0.6934 - accuracy: 0.4981 - binary_crossentropy: 0.6934
# Epoch 68/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.5038 - binary_crossentropy: 0.6933
# Epoch 69/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.4981 - binary_crossentropy: 0.6934
# Epoch 70/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.5038 - binary_crossentropy: 0.6934
# Epoch 71/150
# 210/210 [==============================] - 1s 4ms/step - loss: 0.6934 - accuracy: 0.4838 - binary_crossentropy: 0.6934: 0s - loss: 0.6933 - accuracy: 0.4966 - binary_crossentropy - ETA: 0s - loss: 0.6933 - accuracy: 0.4686 - binary_
# Epoch 72/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.6933 - accuracy: 0.5048 - binary_crossentropy: 0.6933: 0s - loss: 0.691
# Epoch 73/150
# 210/210 [==============================] - 1s 5ms/step - loss: 0.6933 - accuracy: 0.4819 - binary_crossentropy: 0.6933: 1s - loss: 0.6930 - accuracy: 0.
# Epoch 74/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6935 - accuracy: 0.4952 - binary_crossentropy: 0.6935
# Epoch 75/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.5048 - binary_crossentropy: 0.6934
# Epoch 76/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.4790 - binary_crossentropy: 0.6934
# Epoch 77/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6939 - accuracy: 0.5048 - binary_crossentropy: 0.6939
# Epoch 78/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.5048 - binary_crossentropy: 0.6928
# Epoch 79/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6872 - accuracy: 0.5048 - binary_crossentropy: 0.6872
# Epoch 80/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6918 - accuracy: 0.5067 - binary_crossentropy: 0.6918
# Epoch 81/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6865 - accuracy: 0.5267 - binary_crossentropy: 0.6865
# Epoch 82/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6725 - accuracy: 0.5610 - binary_crossentropy: 0.6725
# Epoch 83/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6824 - accuracy: 0.5352 - binary_crossentropy: 0.6824
# Epoch 84/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6782 - accuracy: 0.5343 - binary_crossentropy: 0.6782
# Epoch 85/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6831 - accuracy: 0.5238 - binary_crossentropy: 0.6831
# Epoch 86/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6863 - accuracy: 0.5143 - binary_crossentropy: 0.6863
# Epoch 87/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6664 - accuracy: 0.5629 - binary_crossentropy: 0.6664
# Epoch 88/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6625 - accuracy: 0.6000 - binary_crossentropy: 0.6625
# Epoch 89/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6832 - accuracy: 0.5429 - binary_crossentropy: 0.6832
# Epoch 90/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6893 - accuracy: 0.5124 - binary_crossentropy: 0.6893
# Epoch 91/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6753 - accuracy: 0.5381 - binary_crossentropy: 0.6753: 0s - loss: 0.6647 - accuracy: 0.5519 - binary_crossentro
# Epoch 92/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6789 - accuracy: 0.5429 - binary_crossentropy: 0.6789
# Epoch 93/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6652 - accuracy: 0.5562 - binary_crossentropy: 0.6652
# Epoch 94/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6673 - accuracy: 0.5743 - binary_crossentropy: 0.6673
# Epoch 95/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6945 - accuracy: 0.4971 - binary_crossentropy: 0.6945
# Epoch 96/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6935 - accuracy: 0.4971 - binary_crossentropy: 0.6935
# Epoch 97/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.6930 - accuracy: 0.4905 - binary_crossentropy: 0.6930
# Epoch 98/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6929 - accuracy: 0.4943 - binary_crossentropy: 0.6929
# Epoch 99/150
# 210/210 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.4990 - binary_crossentropy: 0.69 - 0s 2ms/step - loss: 0.6928 - accuracy: 0.4933 - binary_crossentropy: 0.6928
# Epoch 100/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6926 - accuracy: 0.4924 - binary_crossentropy: 0.6926
# Epoch 101/150
# 210/210 [==============================] - ETA: 0s - loss: 0.6920 - accuracy: 0.4921 - binary_crossentropy: 0.69 - 1s 3ms/step - loss: 0.6920 - accuracy: 0.4943 - binary_crossentropy: 0.6920
# Epoch 102/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.6902 - accuracy: 0.4905 - binary_crossentropy: 0.6902
# Epoch 103/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.6798 - accuracy: 0.4914 - binary_crossentropy: 0.6798
# Epoch 104/150
# 210/210 [==============================] - 1s 2ms/step - loss: 0.6795 - accuracy: 0.5362 - binary_crossentropy: 0.6795
# Epoch 105/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6771 - accuracy: 0.5714 - binary_crossentropy: 0.6771
# Epoch 106/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6559 - accuracy: 0.5943 - binary_crossentropy: 0.6559
# Epoch 107/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6465 - accuracy: 0.6152 - binary_crossentropy: 0.6465
# Epoch 108/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6713 - accuracy: 0.5695 - binary_crossentropy: 0.6713
# Epoch 109/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6937 - accuracy: 0.5057 - binary_crossentropy: 0.6937
# Epoch 110/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6871 - accuracy: 0.5133 - binary_crossentropy: 0.6871
# Epoch 111/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6692 - accuracy: 0.5695 - binary_crossentropy: 0.6692
# Epoch 112/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6419 - accuracy: 0.6295 - binary_crossentropy: 0.6419
# Epoch 113/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6532 - accuracy: 0.6171 - binary_crossentropy: 0.6532
# Epoch 114/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6272 - accuracy: 0.6333 - binary_crossentropy: 0.6272
# Epoch 115/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6271 - accuracy: 0.6343 - binary_crossentropy: 0.6271
# Epoch 116/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6667 - accuracy: 0.6190 - binary_crossentropy: 0.6667
# Epoch 117/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.7005 - accuracy: 0.5048 - binary_crossentropy: 0.7005
# Epoch 118/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6497 - accuracy: 0.6067 - binary_crossentropy: 0.6497
# Epoch 119/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6322 - accuracy: 0.6314 - binary_crossentropy: 0.6322
# Epoch 120/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6145 - accuracy: 0.6571 - binary_crossentropy: 0.6145
# Epoch 121/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6286 - accuracy: 0.6562 - binary_crossentropy: 0.6286
# Epoch 122/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6133 - accuracy: 0.6543 - binary_crossentropy: 0.6133
# Epoch 123/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6196 - accuracy: 0.6486 - binary_crossentropy: 0.6196
# Epoch 124/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6285 - accuracy: 0.6486 - binary_crossentropy: 0.6285
# Epoch 125/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.5935 - accuracy: 0.6924 - binary_crossentropy: 0.5935
# Epoch 126/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6199 - accuracy: 0.6590 - binary_crossentropy: 0.6199
# Epoch 127/150
# 210/210 [==============================] - 1s 5ms/step - loss: 0.6007 - accuracy: 0.6952 - binary_crossentropy: 0.6007
# Epoch 128/150
# 210/210 [==============================] - 1s 4ms/step - loss: 0.6135 - accuracy: 0.6781 - binary_crossentropy: 0.6135
# Epoch 129/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6256 - accuracy: 0.6333 - binary_crossentropy: 0.6256
# Epoch 130/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.5822 - accuracy: 0.6886 - binary_crossentropy: 0.5822
# Epoch 131/150
# 210/210 [==============================] - ETA: 0s - loss: 0.5988 - accuracy: 0.6955 - binary_crossentropy: 0.59 - 0s 2ms/step - loss: 0.6005 - accuracy: 0.6905 - binary_crossentropy: 0.6005
# Epoch 132/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6859 - accuracy: 0.5829 - binary_crossentropy: 0.6859
# Epoch 133/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.6424 - accuracy: 0.6133 - binary_crossentropy: 0.6424
# Epoch 134/150
# 210/210 [==============================] - 1s 5ms/step - loss: 0.6055 - accuracy: 0.6810 - binary_crossentropy: 0.6055
# Epoch 135/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6229 - accuracy: 0.6552 - binary_crossentropy: 0.6229
# Epoch 136/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.5903 - accuracy: 0.6876 - binary_crossentropy: 0.5903
# Epoch 137/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.5938 - accuracy: 0.6867 - binary_crossentropy: 0.5938
# Epoch 138/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6068 - accuracy: 0.6724 - binary_crossentropy: 0.6068
# Epoch 139/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6110 - accuracy: 0.6590 - binary_crossentropy: 0.6110
# Epoch 140/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.5733 - accuracy: 0.7038 - binary_crossentropy: 0.5733
# Epoch 141/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.5757 - accuracy: 0.6971 - binary_crossentropy: 0.5757
# Epoch 142/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6227 - accuracy: 0.6476 - binary_crossentropy: 0.6227
# Epoch 143/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6012 - accuracy: 0.6733 - binary_crossentropy: 0.6012
# Epoch 144/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6509 - accuracy: 0.6086 - binary_crossentropy: 0.6509
# Epoch 145/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.5732 - accuracy: 0.6924 - binary_crossentropy: 0.5732
# Epoch 146/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6111 - accuracy: 0.6867 - binary_crossentropy: 0.6111
# Epoch 147/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.5935 - accuracy: 0.6848 - binary_crossentropy: 0.5935
# Epoch 148/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6190 - accuracy: 0.6543 - binary_crossentropy: 0.6190
# Epoch 149/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.5831 - accuracy: 0.7048 - binary_crossentropy: 0.5831
# Epoch 150/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.5717 - accuracy: 0.7152 - binary_crossentropy: 0.5717

# %%
result = model.evaluate(X_train,y_train, verbose=0)
print(dict(zip(model.metrics_names, result)))
# Out:
# {'loss': 0.6125995516777039, 'accuracy': 0.6790476441383362, 'binary_crossentropy': 0.6125995516777039}

# %%
X_train, X_test, y_train, y_test = train_test_split(df_new_onehot, label_onehot, test_size = 0.25)

# %%
clf_svm = SVC(random_state = 9, kernel='linear')
other_classifier(clf_svm, X_train, y_train, X_test, y_test)
# Out:
# Training a SVC
# with a training set size of 1050
# Test Precision Score: 0.8343558282208589
# Test Recall Score: 0.7472527472527473
# Test Accuracy Score: 0.7914285714285715
# Test F1-score Score: 0.7884057971014492
# Test Confusion Matrix:
#  [[141  27]
#  [ 46 136]]
# Number of False Positives: 27
# Confusion matrix, without normalization
# [[141  27]
#  [ 46 136]]
# Normalized confusion matrix
# [[0.83928571 0.16071429]
#  [0.25274725 0.74725275]]

# %%
clf_log_reg = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial')
other_classifier(clf_log_reg, X_train, y_train, X_test, y_test)
# Out:
# Training a LogisticRegression
# with a training set size of 1050
# Test Precision Score: 0.8466257668711656
# Test Recall Score: 0.7582417582417582
# Test Accuracy Score: 0.8028571428571428
# Test F1-score Score: 0.7999999999999999
# Test Confusion Matrix:
#  [[143  25]
#  [ 44 138]]
# Number of False Positives: 25
# Confusion matrix, without normalization
# [[143  25]
#  [ 44 138]]
# Normalized confusion matrix
# [[0.85119048 0.14880952]
#  [0.24175824 0.75824176]]

# %%
clf_tree = DecisionTreeClassifier(criterion='entropy', max_depth=8, min_samples_split=5, splitter = 'best', 
                                  min_samples_leaf = 25)

other_classifier(clf_tree, X_train, y_train, X_test, y_test)
# Out:
# Training a DecisionTreeClassifier
# with a training set size of 1050
# Test Precision Score: 0.8435374149659864
# Test Recall Score: 0.6813186813186813
# Test Accuracy Score: 0.7685714285714286
# Test F1-score Score: 0.7537993920972644
# Test Confusion Matrix:
#  [[145  23]
#  [ 58 124]]
# Number of False Positives: 23
# Confusion matrix, without normalization
# [[145  23]
#  [ 58 124]]
# Normalized confusion matrix
# [[0.86309524 0.13690476]
#  [0.31868132 0.68131868]]

# %%
ax = plt.gca()

clf_log_reg_disp = plot_roc_curve(clf_log_reg, X_test, y_test, ax=ax, alpha=0.8)
clf_tree_disp = plot_roc_curve(clf_tree, X_test, y_test, ax=ax, alpha=0.8)
#clf_tree_disp.plot(ax=ax, alpha=0.8)
clf_svm_disp = plot_roc_curve(clf_svm, X_test, y_test, ax=ax, alpha=0.8)
clf_onehot = plot_roc_curve(clf_onehot, X_test, y_test, ax=ax, alpha=0.8)

plt.show()

# %%
# define the model
model = Sequential()

# hidden layer mit 39 inputs, 10 units
model.add(Dense(20, input_dim=39, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(20, activation = 'relu'))

# output layer
model.add(Dense(1, activation='sigmoid'))

# For a multi-class classification problem
history = model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', 'binary_crossentropy'])


model.fit(X_train, y_train, epochs=150, batch_size=5)
# Out:
# Epoch 1/150
# 210/210 [==============================] - 0s 2ms/step - loss: 3.1773 - accuracy: 0.4990 - binary_crossentropy: 3.1773
# Epoch 2/150
# 210/210 [==============================] - 0s 2ms/step - loss: 1.7163 - accuracy: 0.4981 - binary_crossentropy: 1.7163
# Epoch 3/150
# 210/210 [==============================] - 0s 2ms/step - loss: 2.1852 - accuracy: 0.5267 - binary_crossentropy: 2.1852
# Epoch 4/150
# 210/210 [==============================] - 1s 2ms/step - loss: 2.0494 - accuracy: 0.5381 - binary_crossentropy: 2.0494
# Epoch 5/150
# 210/210 [==============================] - 1s 2ms/step - loss: 1.2103 - accuracy: 0.5352 - binary_crossentropy: 1.2103
# Epoch 6/150
# 210/210 [==============================] - 1s 2ms/step - loss: 1.5660 - accuracy: 0.5314 - binary_crossentropy: 1.5660
# Epoch 7/150
# 210/210 [==============================] - 1s 2ms/step - loss: 1.1864 - accuracy: 0.5495 - binary_crossentropy: 1.1864
# Epoch 8/150
# 210/210 [==============================] - 1s 3ms/step - loss: 1.3146 - accuracy: 0.5400 - binary_crossentropy: 1.3146
# Epoch 9/150
# 210/210 [==============================] - 1s 2ms/step - loss: 1.4408 - accuracy: 0.5410 - binary_crossentropy: 1.4408
# Epoch 10/150
# 210/210 [==============================] - 1s 2ms/step - loss: 1.6699 - accuracy: 0.5448 - binary_crossentropy: 1.6699
# Epoch 11/150
# 210/210 [==============================] - 1s 2ms/step - loss: 1.3512 - accuracy: 0.5610 - binary_crossentropy: 1.3512
# Epoch 12/150
# 210/210 [==============================] - 1s 2ms/step - loss: 1.3753 - accuracy: 0.5514 - binary_crossentropy: 1.3753
# Epoch 13/150
# 210/210 [==============================] - 1s 2ms/step - loss: 1.0655 - accuracy: 0.5762 - binary_crossentropy: 1.0655
# Epoch 14/150
# 210/210 [==============================] - 1s 2ms/step - loss: 0.7558 - accuracy: 0.6476 - binary_crossentropy: 0.7558
# Epoch 15/150
# 210/210 [==============================] - 1s 2ms/step - loss: 0.8064 - accuracy: 0.6419 - binary_crossentropy: 0.8064
# Epoch 16/150
# 210/210 [==============================] - 1s 2ms/step - loss: 0.9803 - accuracy: 0.6162 - binary_crossentropy: 0.9803
# Epoch 17/150
# 210/210 [==============================] - 1s 3ms/step - loss: 1.1460 - accuracy: 0.5848 - binary_crossentropy: 1.1460
# Epoch 18/150
# 210/210 [==============================] - 1s 2ms/step - loss: 1.0512 - accuracy: 0.6324 - binary_crossentropy: 1.0512
# Epoch 19/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.9578 - accuracy: 0.6095 - binary_crossentropy: 0.9578
# Epoch 20/150
# 210/210 [==============================] - 1s 4ms/step - loss: 0.7309 - accuracy: 0.6514 - binary_crossentropy: 0.7309
# Epoch 21/150
# 210/210 [==============================] - 1s 2ms/step - loss: 0.7041 - accuracy: 0.6790 - binary_crossentropy: 0.7041
# Epoch 22/150
# 210/210 [==============================] - 1s 3ms/step - loss: 1.0071 - accuracy: 0.6410 - binary_crossentropy: 1.0071
# Epoch 23/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6481 - accuracy: 0.7095 - binary_crossentropy: 0.6481
# Epoch 24/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6540 - accuracy: 0.7248 - binary_crossentropy: 0.6540
# Epoch 25/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.7372 - accuracy: 0.6962 - binary_crossentropy: 0.7372
# Epoch 26/150
# 210/210 [==============================] - 2s 8ms/step - loss: 0.6389 - accuracy: 0.7448 - binary_crossentropy: 0.6389
# Epoch 27/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.6713 - accuracy: 0.7200 - binary_crossentropy: 0.6713
# Epoch 28/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.5954 - accuracy: 0.7457 - binary_crossentropy: 0.5954
# Epoch 29/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6966 - accuracy: 0.7067 - binary_crossentropy: 0.6966
# Epoch 30/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.6274 - accuracy: 0.7381 - binary_crossentropy: 0.6274
# Epoch 31/150
# 210/210 [==============================] - 1s 2ms/step - loss: 0.6232 - accuracy: 0.7533 - binary_crossentropy: 0.6232
# Epoch 32/150
# 210/210 [==============================] - 1s 2ms/step - loss: 0.5426 - accuracy: 0.7705 - binary_crossentropy: 0.5426
# Epoch 33/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5406 - accuracy: 0.7724 - binary_crossentropy: 0.5406
# Epoch 34/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.7369 - accuracy: 0.7105 - binary_crossentropy: 0.7369
# Epoch 35/150
# 210/210 [==============================] - 1s 2ms/step - loss: 0.6100 - accuracy: 0.7362 - binary_crossentropy: 0.6100
# Epoch 36/150
# 210/210 [==============================] - 1s 2ms/step - loss: 0.6581 - accuracy: 0.7352 - binary_crossentropy: 0.6581
# Epoch 37/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5500 - accuracy: 0.7486 - binary_crossentropy: 0.5500
# Epoch 38/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5900 - accuracy: 0.7448 - binary_crossentropy: 0.5900
# Epoch 39/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5616 - accuracy: 0.7638 - binary_crossentropy: 0.5616
# Epoch 40/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5388 - accuracy: 0.7810 - binary_crossentropy: 0.5388
# Epoch 41/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4994 - accuracy: 0.7838 - binary_crossentropy: 0.4994
# Epoch 42/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5532 - accuracy: 0.7476 - binary_crossentropy: 0.5532
# Epoch 43/150
# 210/210 [==============================] - ETA: 0s - loss: 0.6516 - accuracy: 0.7307 - binary_crossentropy: 0.65 - 1s 3ms/step - loss: 0.6489 - accuracy: 0.7314 - binary_crossentropy: 0.6489
# Epoch 44/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5571 - accuracy: 0.7724 - binary_crossentropy: 0.5571
# Epoch 45/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6055 - accuracy: 0.7562 - binary_crossentropy: 0.6055
# Epoch 46/150
# 210/210 [==============================] - 2s 7ms/step - loss: 0.5506 - accuracy: 0.7638 - binary_crossentropy: 0.5506
# Epoch 47/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5804 - accuracy: 0.7486 - binary_crossentropy: 0.5804
# Epoch 48/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5278 - accuracy: 0.7648 - binary_crossentropy: 0.5278
# Epoch 49/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5971 - accuracy: 0.7238 - binary_crossentropy: 0.5971
# Epoch 50/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6092 - accuracy: 0.6914 - binary_crossentropy: 0.6092
# Epoch 51/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.5573 - accuracy: 0.7495 - binary_crossentropy: 0.5573: 0s - loss: 0.5076 - accuracy: 0.
# Epoch 52/150
# 210/210 [==============================] - 2s 8ms/step - loss: 0.6335 - accuracy: 0.6467 - binary_crossentropy: 0.6335: 0s - loss: 0.6339 - accuracy: 0.6465 - binary_crossentropy: 0.63
# Epoch 53/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5740 - accuracy: 0.7067 - binary_crossentropy: 0.5740
# Epoch 54/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6466 - accuracy: 0.6248 - binary_crossentropy: 0.6466
# Epoch 55/150
# 210/210 [==============================] - 1s 2ms/step - loss: 0.5913 - accuracy: 0.6933 - binary_crossentropy: 0.5913
# Epoch 56/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6064 - accuracy: 0.6695 - binary_crossentropy: 0.6064
# Epoch 57/150
# 210/210 [==============================] - 1s 2ms/step - loss: 0.5916 - accuracy: 0.6933 - binary_crossentropy: 0.5916
# Epoch 58/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6041 - accuracy: 0.6981 - binary_crossentropy: 0.6041
# Epoch 59/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6075 - accuracy: 0.6771 - binary_crossentropy: 0.6075
# Epoch 60/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6206 - accuracy: 0.6695 - binary_crossentropy: 0.6206
# Epoch 61/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6118 - accuracy: 0.6590 - binary_crossentropy: 0.6118
# Epoch 62/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5562 - accuracy: 0.7467 - binary_crossentropy: 0.5562
# Epoch 63/150
# 210/210 [==============================] - 1s 2ms/step - loss: 0.5926 - accuracy: 0.6952 - binary_crossentropy: 0.5926
# Epoch 64/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6012 - accuracy: 0.6762 - binary_crossentropy: 0.6012
# Epoch 65/150
# 210/210 [==============================] - 1s 2ms/step - loss: 0.5663 - accuracy: 0.7229 - binary_crossentropy: 0.5663
# Epoch 66/150
# 210/210 [==============================] - 1s 2ms/step - loss: 0.6511 - accuracy: 0.6114 - binary_crossentropy: 0.6511
# Epoch 67/150
# 210/210 [==============================] - 1s 2ms/step - loss: 0.5890 - accuracy: 0.7057 - binary_crossentropy: 0.5890
# Epoch 68/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6189 - accuracy: 0.6667 - binary_crossentropy: 0.6189
# Epoch 69/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5674 - accuracy: 0.7171 - binary_crossentropy: 0.5674: 0s - loss: 0.5667 - accuracy: 0.7448 - binary_cr
# Epoch 70/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5719 - accuracy: 0.7162 - binary_crossentropy: 0.5719
# Epoch 71/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.6346 - accuracy: 0.6419 - binary_crossentropy: 0.6346
# Epoch 72/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5551 - accuracy: 0.7371 - binary_crossentropy: 0.5551: 0s - loss: 0.5514 - accuracy: 0.7623 - binary_cr
# Epoch 73/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5926 - accuracy: 0.6905 - binary_crossentropy: 0.5926
# Epoch 74/150
# 210/210 [==============================] - 1s 4ms/step - loss: 0.5963 - accuracy: 0.6838 - binary_crossentropy: 0.5963
# Epoch 75/150
# 210/210 [==============================] - 2s 9ms/step - loss: 0.5671 - accuracy: 0.7190 - binary_crossentropy: 0.5671: 0s - loss: 0.5709 - accuracy: 0.7161 - binary_crossentropy: 0.57
# Epoch 76/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.5541 - accuracy: 0.7476 - binary_crossentropy: 0.5541
# Epoch 77/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5343 - accuracy: 0.7562 - binary_crossentropy: 0.5343
# Epoch 78/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6332 - accuracy: 0.6448 - binary_crossentropy: 0.6332
# Epoch 79/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6363 - accuracy: 0.6581 - binary_crossentropy: 0.6363
# Epoch 80/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5919 - accuracy: 0.6905 - binary_crossentropy: 0.5919
# Epoch 81/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5490 - accuracy: 0.7514 - binary_crossentropy: 0.5490
# Epoch 82/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5783 - accuracy: 0.7019 - binary_crossentropy: 0.5783
# Epoch 83/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5493 - accuracy: 0.7333 - binary_crossentropy: 0.5493
# Epoch 84/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5681 - accuracy: 0.7152 - binary_crossentropy: 0.5681
# Epoch 85/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5485 - accuracy: 0.7324 - binary_crossentropy: 0.5485
# Epoch 86/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6846 - accuracy: 0.5886 - binary_crossentropy: 0.6846
# Epoch 87/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6625 - accuracy: 0.5952 - binary_crossentropy: 0.6625
# Epoch 88/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5782 - accuracy: 0.7029 - binary_crossentropy: 0.5782
# Epoch 89/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5476 - accuracy: 0.7543 - binary_crossentropy: 0.5476
# Epoch 90/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5491 - accuracy: 0.7514 - binary_crossentropy: 0.5491
# Epoch 91/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.6290 - accuracy: 0.6438 - binary_crossentropy: 0.6290
# Epoch 92/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5612 - accuracy: 0.7257 - binary_crossentropy: 0.5612
# Epoch 93/150
# 210/210 [==============================] - 1s 4ms/step - loss: 0.5330 - accuracy: 0.7467 - binary_crossentropy: 0.5330
# Epoch 94/150
# 210/210 [==============================] - 1s 6ms/step - loss: 0.5770 - accuracy: 0.7105 - binary_crossentropy: 0.5770
# Epoch 95/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5427 - accuracy: 0.7390 - binary_crossentropy: 0.5427
# Epoch 96/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5274 - accuracy: 0.7714 - binary_crossentropy: 0.5274
# Epoch 97/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.5596 - accuracy: 0.7143 - binary_crossentropy: 0.5596: 0s - loss: 0.5567 - accuracy: 0.7156 - binary_crossentropy:
# Epoch 98/150
# 210/210 [==============================] - 2s 8ms/step - loss: 0.5492 - accuracy: 0.7324 - binary_crossentropy: 0.5492
# Epoch 99/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5786 - accuracy: 0.7076 - binary_crossentropy: 0.5786
# Epoch 100/150
# 210/210 [==============================] - 1s 2ms/step - loss: 0.4903 - accuracy: 0.7819 - binary_crossentropy: 0.4903
# Epoch 101/150
# 210/210 [==============================] - 0s 2ms/step - loss: 0.5673 - accuracy: 0.7229 - binary_crossentropy: 0.5673
# Epoch 102/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5725 - accuracy: 0.7133 - binary_crossentropy: 0.5725
# Epoch 103/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5403 - accuracy: 0.7381 - binary_crossentropy: 0.5403
# Epoch 104/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5366 - accuracy: 0.7505 - binary_crossentropy: 0.5366: 0s - loss: 0.5552 - accuracy: 0.7095 - binary_cr
# Epoch 105/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5124 - accuracy: 0.7781 - binary_crossentropy: 0.5124
# Epoch 106/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5649 - accuracy: 0.7267 - binary_crossentropy: 0.5649
# Epoch 107/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5492 - accuracy: 0.7429 - binary_crossentropy: 0.5492
# Epoch 108/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5206 - accuracy: 0.7667 - binary_crossentropy: 0.5206
# Epoch 109/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5043 - accuracy: 0.7810 - binary_crossentropy: 0.5043
# Epoch 110/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5146 - accuracy: 0.7619 - binary_crossentropy: 0.5146
# Epoch 111/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5160 - accuracy: 0.7638 - binary_crossentropy: 0.5160
# Epoch 112/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4906 - accuracy: 0.7810 - binary_crossentropy: 0.4906
# Epoch 113/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5427 - accuracy: 0.7467 - binary_crossentropy: 0.5427
# Epoch 114/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5137 - accuracy: 0.7771 - binary_crossentropy: 0.5137: 0s - loss: 0.5423 - accuracy: 0.7806 - binary_cr
# Epoch 115/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5430 - accuracy: 0.7390 - binary_crossentropy: 0.5430
# Epoch 116/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4853 - accuracy: 0.7943 - binary_crossentropy: 0.4853
# Epoch 117/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4906 - accuracy: 0.7952 - binary_crossentropy: 0.4906
# Epoch 118/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5466 - accuracy: 0.7562 - binary_crossentropy: 0.5466
# Epoch 119/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4724 - accuracy: 0.8019 - binary_crossentropy: 0.4724
# Epoch 120/150
# 210/210 [==============================] - 1s 4ms/step - loss: 0.5210 - accuracy: 0.7676 - binary_crossentropy: 0.5210
# Epoch 121/150
# 210/210 [==============================] - 2s 9ms/step - loss: 0.4849 - accuracy: 0.7914 - binary_crossentropy: 0.4849: 0s - loss: 0.4841 - accuracy: 0.7947 - binary_crossentropy:
# Epoch 122/150
# 210/210 [==============================] - 1s 5ms/step - loss: 0.5394 - accuracy: 0.7533 - binary_crossentropy: 0.5394
# Epoch 123/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5622 - accuracy: 0.7333 - binary_crossentropy: 0.5622
# Epoch 124/150
# 210/210 [==============================] - 1s 2ms/step - loss: 0.4877 - accuracy: 0.7886 - binary_crossentropy: 0.4877
# Epoch 125/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5509 - accuracy: 0.7524 - binary_crossentropy: 0.5509
# Epoch 126/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4998 - accuracy: 0.7752 - binary_crossentropy: 0.4998: 0s - loss: 0.5017 - accuracy: 0.7757 - binary_crossentropy: 0.
# Epoch 127/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4748 - accuracy: 0.7943 - binary_crossentropy: 0.4748
# Epoch 128/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5402 - accuracy: 0.7552 - binary_crossentropy: 0.5402
# Epoch 129/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4951 - accuracy: 0.7876 - binary_crossentropy: 0.4951
# Epoch 130/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5249 - accuracy: 0.7590 - binary_crossentropy: 0.5249
# Epoch 131/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4725 - accuracy: 0.7952 - binary_crossentropy: 0.4725
# Epoch 132/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5157 - accuracy: 0.7695 - binary_crossentropy: 0.5157
# Epoch 133/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4905 - accuracy: 0.7810 - binary_crossentropy: 0.4905
# Epoch 134/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4814 - accuracy: 0.7800 - binary_crossentropy: 0.4814
# Epoch 135/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4803 - accuracy: 0.8038 - binary_crossentropy: 0.4803
# Epoch 136/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4795 - accuracy: 0.7924 - binary_crossentropy: 0.4795
# Epoch 137/150
# 210/210 [==============================] - ETA: 0s - loss: 0.5189 - accuracy: 0.7769 - binary_crossentropy: 0.51 - 1s 3ms/step - loss: 0.5132 - accuracy: 0.7800 - binary_crossentropy: 0.5132
# Epoch 138/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4645 - accuracy: 0.8048 - binary_crossentropy: 0.4645
# Epoch 139/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4569 - accuracy: 0.8105 - binary_crossentropy: 0.4569
# Epoch 140/150
# 210/210 [==============================] - 2s 7ms/step - loss: 0.5097 - accuracy: 0.7657 - binary_crossentropy: 0.5097: 0s - loss: 0.4932 -
# Epoch 141/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5042 - accuracy: 0.7810 - binary_crossentropy: 0.5042
# Epoch 142/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4832 - accuracy: 0.7876 - binary_crossentropy: 0.4832
# Epoch 143/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4798 - accuracy: 0.7905 - binary_crossentropy: 0.4798
# Epoch 144/150
# 210/210 [==============================] - 1s 7ms/step - loss: 0.5099 - accuracy: 0.7686 - binary_crossentropy: 0.5099: 0s - loss: 0.5065 - accuracy: 0.7701 - binary_crosse
# Epoch 145/150
# 210/210 [==============================] - 2s 8ms/step - loss: 0.4573 - accuracy: 0.8114 - binary_crossentropy: 0.4573: 0s - loss: 0.4610 - accuracy: 0.8125 - b - ETA: 0s - loss: 0.4576 - accuracy: 0.8105 - binary_crossentro
# Epoch 146/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4950 - accuracy: 0.7905 - binary_crossentropy: 0.4950
# Epoch 147/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4736 - accuracy: 0.7914 - binary_crossentropy: 0.4736
# Epoch 148/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4416 - accuracy: 0.8048 - binary_crossentropy: 0.4416
# Epoch 149/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.5088 - accuracy: 0.7705 - binary_crossentropy: 0.5088
# Epoch 150/150
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4810 - accuracy: 0.7905 - binary_crossentropy: 0.4810

# %%
result = model.evaluate(X_train,y_train, verbose=0)
print(dict(zip(model.metrics_names, result)))
# Out:
# {'loss': 0.4545825123786926, 'accuracy': 0.8038095235824585, 'binary_crossentropy': 0.4545825123786926}
